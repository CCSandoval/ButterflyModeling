# %% [markdown]
# # 03 · EfficientNetB0 (estudiante 3/4)
#
# Escalado compuesto de profundidad, ancho y resolución sobre bloques MBConv: 4.88M parámetros, 104 ms/imagen, ~2.3 min/época. El más pesado del grupo de estudiantes.
#
# Comparte familia con EfficientNetV2B0, que compite como docente, pero es otra generación y aquí entra por el extremo barato: menos parámetros y menor latencia que el docente.
#
# Candidato a **estudiante**. Al estudiante no se le elige maximizando calidad (eso devolvería al docente) sino por costo/calidad: es el modelo que termina desplegado en el prototipo.
#
# Misma cabeza de clasificación y mismo régimen de entrenamiento que el resto de la comparación (Adam 1e-3, class_weight balanceado, EarlyStopping patience 8, semilla 42), cambiando solo el backbone.

# %%
import os
import sys
from pathlib import Path

ROOT = Path.cwd()
while not (ROOT / "corpus.json").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print("Raíz del proyecto:", ROOT)
# Out:
# Raíz del proyecto: /Users/cristiansandoval/Universidad/Semillero/ButterflyModeling

# %%
import platform
from datetime import datetime, timezone

import numpy as np
import pandas as pd
import tensorflow as tf

from scripts import corpus, evalStats
from scripts import modelRegistry as registro
from scripts.architectures import buildModel, preprocessFn
from scripts.dataPipeline import buildAugmenter, loadSplit, preparar
from scripts.vizStyle import SERIE_1, SERIE_2, applyStyle, plotConfusionMatrix

ARQUITECTURA = "efficientnet_b0"
RUN_NAME = "efficientnet-b0"
NOTAS = "Candidato a estudiante: efficientnet-b0 + cabeza comun"
ROL = "estudiante"
PROMOVER = False

TAMANO = (320, 320)
LOTE = 32
EPOCAS = 50
PACIENCIA = 8
TASA_APRENDIZAJE = 1e-3
SEMILLA = 42

tf.keras.utils.set_random_seed(SEMILLA)
corpus.materializar()

RUN_ID = registro.buildRunId(RUN_NAME)
RUN_DIR = registro.createRunDir(RUN_ID)
IMGS = RUN_DIR / "imgs"

print(f"run_id : {RUN_ID}")
print(f"TF     : {tf.__version__} · dispositivos: "
      f"{[d.device_type for d in tf.config.list_physical_devices()]}")
# Out:
# run_id : 20260906T173406Z_efficientnet-b0
# TF     : 2.19.1 · dispositivos: ['CPU']

# %% [markdown]
# ## 1 · Datos
#
# Un tf.data.Dataset por split. Solo `train` se aumenta; `validate`/`test` son
# deterministas (`shuffle=False`, indispensable para que `y_true` se alinee con
# las predicciones).

# %%
preprocess = preprocessFn(ARQUITECTURA)
augmentador = buildAugmenter()

dsTrainCrudo, clases = loadSplit("dataset/train", TAMANO, LOTE)
dsValCrudo, _ = loadSplit("dataset/validate", TAMANO, LOTE, shuffle=False)
dsTestCrudo, _ = loadSplit("dataset/test", TAMANO, LOTE, shuffle=False)

dsTrain = preparar(dsTrainCrudo, preprocess, augmentador)
dsVal = preparar(dsValCrudo, preprocess)
dsTest = preparar(dsTestCrudo, preprocess)

print(f"{len(clases)} clases")
# Out:
# Found 7218 files belonging to 79 classes.
# Found 1038 files belonging to 79 classes.
# Found 2062 files belonging to 79 classes.
# 79 clases

# %% [markdown]
# ## 2 · Modelo

# %%
modelo = buildModel(ARQUITECTURA, len(clases))

entrenables = sum(int(np.prod(w.shape)) for w in modelo.trainable_weights)
congelados = sum(int(np.prod(w.shape)) for w in modelo.non_trainable_weights)
pd.Series({
    "parametros_totales": modelo.count_params(),
    "entrenables": entrenables,
    "congelados": congelados,
    "clases_salida": len(clases),
}).to_frame("valor")
# Out:
#                       valor
# parametros_totales  4883442
# entrenables          832079
# congelados          4051363
# clases_salida            79

# %% [markdown]
# ## 3 · Pesos de clase

# %%
pesosClase = corpus.classWeights()
pd.Series(
    {clases[i]: round(p, 3) for i, p in pesosClase.items()}
).sort_values(ascending=False).head(8).to_frame("peso")
# Out:
#                        peso
# autochton_itylus      3.151
# taygetis_sylvia       3.151
# cissia_confusa        3.151
# pseudodebis_puritana  3.046
# pyrgus_adepta         2.947
# pteronymia_latilla    2.125
# euselasia_mys         2.077
# pteronymia_aletta     1.986

# %% [markdown]
# ## 4 · Entrenamiento

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

modelo.compile(
    loss="categorical_crossentropy",
    optimizer=Adam(learning_rate=TASA_APRENDIZAJE),
    metrics=["accuracy"],
)

callbacks = [
    EarlyStopping(monitor="val_loss", patience=PACIENCIA,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3,
                       min_lr=1e-6, verbose=1),
]

inicio = datetime.now(timezone.utc)
ajuste = modelo.fit(
    dsTrain,
    validation_data=dsVal,
    epochs=EPOCAS,
    callbacks=callbacks,
    class_weight=pesosClase,
)
fin = datetime.now(timezone.utc)

historia = {k: [float(v) for v in vs] for k, vs in ajuste.history.items()}
print(f"\n{len(historia['loss'])} épocas en {(fin - inicio).total_seconds() / 60:.1f} min")
# Out:
# Epoch 1/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 185s 798ms/step - accuracy: 0.1143 - loss: 3.9963 - val_accuracy: 0.3892 - val_loss: 2.4942 - learning_rate: 0.0010
# Epoch 2/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 244s 1s/step - accuracy: 0.2999 - loss: 2.6618 - val_accuracy: 0.5636 - val_loss: 1.6390 - learning_rate: 0.0010
# Epoch 3/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 234s 1s/step - accuracy: 0.4093 - loss: 2.1685 - val_accuracy: 0.6252 - val_loss: 1.3184 - learning_rate: 0.0010
# Epoch 4/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 234s 1s/step - accuracy: 0.4710 - loss: 1.8582 - val_accuracy: 0.6570 - val_loss: 1.1608 - learning_rate: 0.0010
# Epoch 5/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 237s 1s/step - accuracy: 0.5150 - loss: 1.6931 - val_accuracy: 0.6744 - val_loss: 1.0664 - learning_rate: 0.0010
# Epoch 6/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 241s 1s/step - accuracy: 0.5298 - loss: 1.6020 - val_accuracy: 0.7004 - val_loss: 0.9981 - learning_rate: 0.0010
# Epoch 7/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 241s 1s/step - accuracy: 0.5643 - loss: 1.4707 - val_accuracy: 0.7119 - val_loss: 0.9650 - learning_rate: 0.0010
# Epoch 8/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 245s 1s/step - accuracy: 0.5896 - loss: 1.3981 - val_accuracy: 0.7168 - val_loss: 0.8971 - learning_rate: 0.0010
# Epoch 9/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 245s 1s/step - accuracy: 0.5993 - loss: 1.3298 - val_accuracy: 0.7206 - val_loss: 0.8923 - learning_rate: 0.0010
# Epoch 10/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 257s 1s/step - accuracy: 0.6101 - loss: 1.2859 - val_accuracy: 0.7457 - val_loss: 0.8248 - learning_rate: 0.0010
# Epoch 11/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 243s 1s/step - accuracy: 0.6360 - loss: 1.1977 - val_accuracy: 0.7312 - val_loss: 0.8203 - learning_rate: 0.0010
# Epoch 12/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 243s 1s/step - accuracy: 0.6373 - loss: 1.2070 - val_accuracy: 0.7524 - val_loss: 0.7913 - learning_rate: 0.0010
# Epoch 13/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 243s 1s/step - accuracy: 0.6473 - loss: 1.1536 - val_accuracy: 0.7543 - val_loss: 0.7536 - learning_rate: 0.0010
# Epoch 14/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.6538 - loss: 1.1130 - val_accuracy: 0.7303 - val_loss: 0.8517 - learning_rate: 0.0010
# Epoch 15/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 247s 1s/step - accuracy: 0.6624 - loss: 1.0918 - val_accuracy: 0.7524 - val_loss: 0.7400 - learning_rate: 0.0010
# Epoch 16/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 247s 1s/step - accuracy: 0.6663 - loss: 1.0780 - val_accuracy: 0.7543 - val_loss: 0.7422 - learning_rate: 0.0010
# Epoch 17/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 247s 1s/step - accuracy: 0.6694 - loss: 1.0684 - val_accuracy: 0.7775 - val_loss: 0.6992 - learning_rate: 0.0010
# Epoch 18/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - accuracy: 0.6874 - loss: 1.0013 - val_accuracy: 0.7890 - val_loss: 0.6936 - learning_rate: 0.0010
# Epoch 19/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 247s 1s/step - accuracy: 0.6868 - loss: 1.0024 - val_accuracy: 0.7697 - val_loss: 0.7100 - learning_rate: 0.0010
# Epoch 20/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - accuracy: 0.6858 - loss: 0.9717 - val_accuracy: 0.7909 - val_loss: 0.6459 - learning_rate: 0.0010
# Epoch 21/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 247s 1s/step - accuracy: 0.6911 - loss: 0.9771 - val_accuracy: 0.7881 - val_loss: 0.6796 - learning_rate: 0.0010
# Epoch 22/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - accuracy: 0.7019 - loss: 0.9543 - val_accuracy: 0.7784 - val_loss: 0.6818 - learning_rate: 0.0010
# Epoch 23/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 989ms/step - accuracy: 0.7004 - loss: 0.9337
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 255s 1s/step - accuracy: 0.6966 - loss: 0.9512 - val_accuracy: 0.7958 - val_loss: 0.6520 - learning_rate: 0.0010
# Epoch 24/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 253s 1s/step - accuracy: 0.7265 - loss: 0.8398 - val_accuracy: 0.8092 - val_loss: 0.6247 - learning_rate: 3.0000e-04
# Epoch 25/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 247s 1s/step - accuracy: 0.7480 - loss: 0.7916 - val_accuracy: 0.8015 - val_loss: 0.6246 - learning_rate: 3.0000e-04
# Epoch 26/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 246s 1s/step - accuracy: 0.7562 - loss: 0.7528 - val_accuracy: 0.8092 - val_loss: 0.6187 - learning_rate: 3.0000e-04
# Epoch 27/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 249s 1s/step - accuracy: 0.7571 - loss: 0.7440 - val_accuracy: 0.8083 - val_loss: 0.5971 - learning_rate: 3.0000e-04
# Epoch 28/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 250s 1s/step - accuracy: 0.7577 - loss: 0.7400 - val_accuracy: 0.8083 - val_loss: 0.6117 - learning_rate: 3.0000e-04
# Epoch 29/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.7606 - loss: 0.7258 - val_accuracy: 0.8112 - val_loss: 0.6132 - learning_rate: 3.0000e-04
# Epoch 30/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.7670 - loss: 0.7153 - val_accuracy: 0.8150 - val_loss: 0.5899 - learning_rate: 3.0000e-04
# Epoch 31/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.7711 - loss: 0.7273 - val_accuracy: 0.8343 - val_loss: 0.5654 - learning_rate: 3.0000e-04
# Epoch 32/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.7661 - loss: 0.6960 - val_accuracy: 0.8256 - val_loss: 0.5672 - learning_rate: 3.0000e-04
# Epoch 33/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.7822 - loss: 0.6801 - val_accuracy: 0.8276 - val_loss: 0.5692 - learning_rate: 3.0000e-04
# Epoch 34/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 991ms/step - accuracy: 0.7789 - loss: 0.6827
# Epoch 34: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.7850 - loss: 0.6681 - val_accuracy: 0.8208 - val_loss: 0.5739 - learning_rate: 3.0000e-04
# Epoch 35/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 257s 1s/step - accuracy: 0.8002 - loss: 0.6374 - val_accuracy: 0.8285 - val_loss: 0.5571 - learning_rate: 9.0000e-05
# Epoch 36/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 257s 1s/step - accuracy: 0.7902 - loss: 0.6542 - val_accuracy: 0.8343 - val_loss: 0.5503 - learning_rate: 9.0000e-05
# Epoch 37/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.7889 - loss: 0.6484 - val_accuracy: 0.8372 - val_loss: 0.5467 - learning_rate: 9.0000e-05
# Epoch 38/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - accuracy: 0.7951 - loss: 0.6088 - val_accuracy: 0.8372 - val_loss: 0.5476 - learning_rate: 9.0000e-05
# Epoch 39/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 258s 1s/step - accuracy: 0.7947 - loss: 0.6348 - val_accuracy: 0.8353 - val_loss: 0.5480 - learning_rate: 9.0000e-05
# Epoch 40/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 993ms/step - accuracy: 0.7998 - loss: 0.6088
# Epoch 40: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 255s 1s/step - accuracy: 0.8013 - loss: 0.6091 - val_accuracy: 0.8362 - val_loss: 0.5485 - learning_rate: 9.0000e-05
# Epoch 41/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 253s 1s/step - accuracy: 0.7970 - loss: 0.6232 - val_accuracy: 0.8382 - val_loss: 0.5468 - learning_rate: 2.7000e-05
# Epoch 42/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 253s 1s/step - accuracy: 0.8051 - loss: 0.6016 - val_accuracy: 0.8410 - val_loss: 0.5439 - learning_rate: 2.7000e-05
# Epoch 43/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 256s 1s/step - accuracy: 0.8131 - loss: 0.5793 - val_accuracy: 0.8382 - val_loss: 0.5402 - learning_rate: 2.7000e-05
# Epoch 44/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 255s 1s/step - accuracy: 0.8060 - loss: 0.5900 - val_accuracy: 0.8372 - val_loss: 0.5449 - learning_rate: 2.7000e-05
# Epoch 45/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 256s 1s/step - accuracy: 0.8101 - loss: 0.5774 - val_accuracy: 0.8372 - val_loss: 0.5419 - learning_rate: 2.7000e-05
# Epoch 46/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 971ms/step - accuracy: 0.7974 - loss: 0.6019
# Epoch 46: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.7968 - loss: 0.6070 - val_accuracy: 0.8401 - val_loss: 0.5424 - learning_rate: 2.7000e-05
# Epoch 47/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.8011 - loss: 0.6011 - val_accuracy: 0.8382 - val_loss: 0.5441 - learning_rate: 8.1000e-06
# Epoch 48/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.8048 - loss: 0.5942 - val_accuracy: 0.8353 - val_loss: 0.5438 - learning_rate: 8.1000e-06
# Epoch 49/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 979ms/step - accuracy: 0.8051 - loss: 0.5945
# Epoch 49: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.8023 - loss: 0.5985 - val_accuracy: 0.8353 - val_loss: 0.5423 - learning_rate: 8.1000e-06
# Epoch 50/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.8042 - loss: 0.5970 - val_accuracy: 0.8343 - val_loss: 0.5454 - learning_rate: 2.4300e-06
# Restoring model weights from the end of the best epoch: 43.
#
# 50 épocas en 207.2 min

# %% [markdown]
# ## 5 · Curvas de entrenamiento

# %%
applyStyle()
import matplotlib.pyplot as plt

epocas = range(1, len(historia["loss"]) + 1)
figura, ejes = plt.subplots(1, 2, figsize=(11, 4.2))

ejes[0].plot(epocas, historia["accuracy"], color=SERIE_1, label="Entrenamiento")
ejes[0].plot(epocas, historia["val_accuracy"], color=SERIE_2, label="Validación")
ejes[0].set(title=f"{RUN_NAME} · Exactitud", xlabel="Época", ylim=(0, 1))
ejes[0].legend(loc="lower right")

ejes[1].plot(epocas, historia["loss"], color=SERIE_1, label="Entrenamiento")
ejes[1].plot(epocas, historia["val_loss"], color=SERIE_2, label="Validación")
ejes[1].set(title=f"{RUN_NAME} · Pérdida", xlabel="Época")
ejes[1].legend(loc="upper right")

figura.tight_layout()
figura.savefig(IMGS / "training_history.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 6 · Evaluación
#
# Dos conjuntos: `test` (20%, métrica principal) y `validate` (10%, el que
# monitorean los callbacks).

# %%
metricas = {
    "test": evalStats.evaluar(modelo, dsTest, clases),
    "validate": evalStats.evaluar(modelo, dsVal, clases),
}

pd.DataFrame([
    {k: round(v, 4) if isinstance(v, float) else v
     for k, v in m.items()
     if k in ("num_samples", "accuracy", "top3_accuracy",
              "macro_f1", "weighted_f1", "macro_precision", "macro_recall")}
    for m in metricas.values()
], index=list(metricas.keys()))
# Out:
# 2026-09-06 16:02:17.075809: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-09-06 16:02:45.666620: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
#           num_samples  accuracy  top3_accuracy  macro_precision  macro_recall  \
# test             2062    0.8274         0.9602           0.8279        0.8212
# validate         1038    0.8382         0.9595           0.8502        0.8380
#
#           macro_f1  weighted_f1
# test        0.8159       0.8232
# validate    0.8352       0.8358

# %% [markdown]
# ## 7 · Matriz de confusión

# %%
_ = plotConfusionMatrix(
    metricas["test"],
    f"Matriz de confusión · prueba · {RUN_NAME}",
)
plt.savefig(IMGS / "confusion_test.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 8 · Confusiones principales

# %%
confusiones = evalStats.confusionesPrincipales(metricas["test"])
pd.DataFrame(confusiones).head(10)
# Out:
#                       real                    predicha  casos   tasa
# 0       parides_erithalion           parides_eurimedes     14  0.519
# 1           urbanus_procne          urbanus_simplicius     12  0.400
# 2            eurema_arbela          eurema_xantochlora     10  0.417
# 3      mechanitis_lysimnia          mechanitis_menapis      9  0.281
# 4  archaeoprepona_demophon  archaeoprepona_amphimachus      8  0.276
# 5     heliconius_melpomene            heliconius_erato      8  0.276
# 6          cissia_pompilia        hermeuptychia_hermes      7  0.241
# 7            eurema_arbela              phoebis_sennae      6  0.250
# 8         heliconius_erato        heliconius_melpomene      6  0.240
# 9            consul_fabius          hypna_clytemnestra      6  0.222

# %% [markdown]
# ## 9 · Versionado

# %%
modelo.save(RUN_DIR / "model.keras")
registro.writeJson(RUN_DIR / "history.json", historia)
registro.writeJson(RUN_DIR / "metrics.json", {
    "run_id": RUN_ID,
    "class_names": clases,
    "splits": metricas,
    "top_confusions": {
        s: evalStats.confusionesPrincipales(m) for s, m in metricas.items()
    },
})

configuracion = {
    "run_id": RUN_ID,
    "name": RUN_NAME,
    "architecture": ARQUITECTURA,
    "role": ROL,
    "notes": NOTAS,
    "num_classes": len(clases),
    "hyperparameters": {
        "img_size": list(TAMANO),
        "batch_size": LOTE,
        "epochs_budget": EPOCAS,
        "epochs_ran": len(historia["loss"]),
        "learning_rate": TASA_APRENDIZAJE,
        "early_stopping_patience": PACIENCIA,
        "class_weights": "balanced",
        "seed": SEMILLA,
        "backbone": f"{ARQUITECTURA}/imagenet (congelado)",
    },
    "environment": {
        "python": platform.python_version(),
        "tensorflow": tf.__version__,
        "platform": platform.platform(),
    },
    "started_at": inicio.isoformat(),
    "finished_at": fin.isoformat(),
    "training_minutes": round((fin - inicio).total_seconds() / 60, 1),
}
registro.writeJson(RUN_DIR / "run.json", configuracion)

registro.registerRun({
    "run_id": RUN_ID,
    "name": RUN_NAME,
    "architecture": ARQUITECTURA,
    "role": ROL,
    "num_classes": len(clases),
    "epochs_ran": len(historia["loss"]),
    "training_minutes": configuracion["training_minutes"],
    "test_accuracy": metricas["test"]["accuracy"],
    "test_macro_f1": metricas["test"]["macro_f1"],
    "validate_accuracy": metricas["validate"]["accuracy"],
    "validate_macro_f1": metricas["validate"]["macro_f1"],
    "notes": NOTAS,
    "created_at": inicio.isoformat(),
})

if PROMOVER:
    registro.promoteRun(RUN_ID)

print(f"Run guardado en {RUN_DIR}")
# Out:
# Run guardado en /Users/cristiansandoval/Universidad/Semillero/ButterflyModeling/outputs/runs/20260906T173406Z_efficientnet-b0

# %% [markdown]
# ## Resumen

# %%
pd.Series({
    "run_id": RUN_ID,
    "arquitectura": ARQUITECTURA,
    "clases": len(clases),
    "epocas": len(historia["loss"]),
    "minutos": configuracion["training_minutes"],
    "test_accuracy": round(metricas["test"]["accuracy"], 4),
    "test_top3": round(metricas["test"]["top3_accuracy"], 4),
    "test_macro_f1": round(metricas["test"]["macro_f1"], 4),
    "validate_accuracy": round(metricas["validate"]["accuracy"], 4),
    "validate_macro_f1": round(metricas["validate"]["macro_f1"], 4),
}).to_frame("valor")
# Out:
#                                               valor
# run_id             20260906T173406Z_efficientnet-b0
# arquitectura                        efficientnet_b0
# clases                                           79
# epocas                                           50
# minutos                                       207.2
# test_accuracy                                0.8274
# test_top3                                    0.9602
# test_macro_f1                                0.8159
# validate_accuracy                            0.8382
# validate_macro_f1                            0.8352
