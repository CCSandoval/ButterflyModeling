# %% [markdown]
# # 01 · MobileNetV3Small
#
# Candidato a estudiante. 1.41M parámetros, 44 ms/imagen.

# %%
import os
import sys
from pathlib import Path

ROOT = Path.cwd()
while not (ROOT / "corpus.json").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print("Raíz del proyecto:", ROOT)
# Out:
# Raíz del proyecto: /Users/cristiansandoval/Universidad/Semillero/ButterflyModeling

# %%
import platform
from datetime import datetime, timezone

import numpy as np
import pandas as pd
import tensorflow as tf

from scripts import corpus, evalStats
from scripts import modelRegistry as registro
from scripts.architectures import buildModel, descongelarCola, preprocessFn
from scripts.dataPipeline import buildAugmenter, loadSplit, preparar
from scripts.vizStyle import SERIE_1, SERIE_2, applyStyle, plotConfusionMatrix

ARQUITECTURA = "mobilenet_v3_small"
RUN_NAME = "mobilenet-v3-small"
NOTAS = "Candidato a estudiante: MobileNetV3Small + cabeza comun"
ROL = "estudiante"
PROMOVER = False

# 0.0 reproduce el run con backbone congelado; 0.30 descongela la cola
FRACCION_DESCONGELADA = 0.30

TAMANO = (320, 320)
LOTE = 32
EPOCAS = 50
PACIENCIA = 8
TASA_APRENDIZAJE = 1e-4 if FRACCION_DESCONGELADA else 1e-3
SEMILLA = 42

tf.keras.utils.set_random_seed(SEMILLA)
corpus.materializar()

RUN_ID = registro.buildRunId(RUN_NAME)
RUN_DIR = registro.createRunDir(RUN_ID)
IMGS = RUN_DIR / "imgs"

print(f"run_id : {RUN_ID}")
print(f"TF     : {tf.__version__} · dispositivos: "
      f"{[d.device_type for d in tf.config.list_physical_devices()]}")
# Out:
# run_id : 20260912T044001Z_mobilenet-v3-small
# TF     : 2.19.1 · dispositivos: ['CPU']

# %% [markdown]
# ## 1 · Datos
#
# Un tf.data.Dataset por split. Solo `train` se aumenta; `validate`/`test` son
# deterministas (`shuffle=False`, indispensable para que `y_true` se alinee con
# las predicciones).

# %%
preprocess = preprocessFn(ARQUITECTURA)
augmentador = buildAugmenter()

dsTrainCrudo, clases = loadSplit("dataset/train", TAMANO, LOTE)
dsValCrudo, _ = loadSplit("dataset/validate", TAMANO, LOTE, shuffle=False)
dsTestCrudo, _ = loadSplit("dataset/test", TAMANO, LOTE, shuffle=False)

dsTrain = preparar(dsTrainCrudo, preprocess, augmentador)
dsVal = preparar(dsValCrudo, preprocess)
dsTest = preparar(dsTestCrudo, preprocess)

print(f"{len(clases)} clases")
# Out:
# Found 7218 files belonging to 79 classes.
# Found 1038 files belonging to 79 classes.
# Found 2062 files belonging to 79 classes.
# 79 clases

# %% [markdown]
# ## 2 · Modelo

# %%
modelo = buildModel(ARQUITECTURA, len(clases))
if FRACCION_DESCONGELADA:
    print(descongelarCola(modelo, FRACCION_DESCONGELADA))

entrenables = sum(int(np.prod(w.shape)) for w in modelo.trainable_weights)
congelados = sum(int(np.prod(w.shape)) for w in modelo.non_trainable_weights)
pd.Series({
    "parametros_totales": modelo.count_params(),
    "entrenables": entrenables,
    "congelados": congelados,
    "clases_salida": len(clases),
}).to_frame("valor")
# Out:
# /opt/miniconda3/envs/semillero/lib/python3.12/site-packages/keras/src/applications/mobilenet_v3.py:454: UserWarning: `input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
#   return MobileNetV3(
# {'capas_backbone': 157, 'capas_descongeladas': 38, 'parametros_entrenables': 1200631}
#                       valor
# parametros_totales  1412543
# entrenables         1200631
# congelados           211912
# clases_salida            79

# %% [markdown]
# ## 3 · Pesos de clase

# %%
pesosClase = corpus.classWeights()
pd.Series(
    {clases[i]: round(p, 3) for i, p in pesosClase.items()}
).sort_values(ascending=False).head(8).to_frame("peso")
# Out:
#                        peso
# autochton_itylus      3.151
# taygetis_sylvia       3.151
# cissia_confusa        3.151
# pseudodebis_puritana  3.046
# pyrgus_adepta         2.947
# pteronymia_latilla    2.125
# euselasia_mys         2.077
# pteronymia_aletta     1.986

# %% [markdown]
# ## 4 · Entrenamiento

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

modelo.compile(
    loss="categorical_crossentropy",
    optimizer=Adam(learning_rate=TASA_APRENDIZAJE),
    metrics=["accuracy"],
)

callbacks = [
    EarlyStopping(monitor="val_loss", patience=PACIENCIA,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3,
                       min_lr=1e-6, verbose=1),
]

inicio = datetime.now(timezone.utc)
ajuste = modelo.fit(
    dsTrain,
    validation_data=dsVal,
    epochs=EPOCAS,
    callbacks=callbacks,
    class_weight=pesosClase,
)
fin = datetime.now(timezone.utc)

historia = {k: [float(v) for v in vs] for k, vs in ajuste.history.items()}
print(f"\n{len(historia['loss'])} épocas en {(fin - inicio).total_seconds() / 60:.1f} min")
# Out:
# Epoch 1/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 67s 282ms/step - accuracy: 0.0237 - loss: 5.1484 - val_accuracy: 0.1098 - val_loss: 4.0088 - learning_rate: 1.0000e-04
# Epoch 2/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 62s 273ms/step - accuracy: 0.0611 - loss: 4.4755 - val_accuracy: 0.2322 - val_loss: 3.3036 - learning_rate: 1.0000e-04
# Epoch 3/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 64s 278ms/step - accuracy: 0.1129 - loss: 3.8858 - val_accuracy: 0.3333 - val_loss: 2.7959 - learning_rate: 1.0000e-04
# Epoch 4/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 74s 323ms/step - accuracy: 0.1847 - loss: 3.4566 - val_accuracy: 0.4249 - val_loss: 2.3998 - learning_rate: 1.0000e-04
# Epoch 5/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 76s 332ms/step - accuracy: 0.2321 - loss: 3.1321 - val_accuracy: 0.4990 - val_loss: 2.1354 - learning_rate: 1.0000e-04
# Epoch 6/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 75s 329ms/step - accuracy: 0.2823 - loss: 2.8713 - val_accuracy: 0.5597 - val_loss: 1.9229 - learning_rate: 1.0000e-04
# Epoch 7/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 75s 329ms/step - accuracy: 0.3220 - loss: 2.6506 - val_accuracy: 0.5992 - val_loss: 1.7463 - learning_rate: 1.0000e-04
# Epoch 8/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 76s 334ms/step - accuracy: 0.3750 - loss: 2.4456 - val_accuracy: 0.6262 - val_loss: 1.5919 - learning_rate: 1.0000e-04
# Epoch 9/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 77s 335ms/step - accuracy: 0.4081 - loss: 2.2866 - val_accuracy: 0.6320 - val_loss: 1.4627 - learning_rate: 1.0000e-04
# Epoch 10/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 84s 370ms/step - accuracy: 0.4474 - loss: 2.1248 - val_accuracy: 0.6474 - val_loss: 1.4415 - learning_rate: 1.0000e-04
# Epoch 11/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 344ms/step - accuracy: 0.4744 - loss: 2.0236 - val_accuracy: 0.6782 - val_loss: 1.3161 - learning_rate: 1.0000e-04
# Epoch 12/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 344ms/step - accuracy: 0.5075 - loss: 1.8713 - val_accuracy: 0.6956 - val_loss: 1.2357 - learning_rate: 1.0000e-04
# Epoch 13/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 344ms/step - accuracy: 0.5359 - loss: 1.7661 - val_accuracy: 0.7187 - val_loss: 1.1550 - learning_rate: 1.0000e-04
# Epoch 14/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 78s 342ms/step - accuracy: 0.5571 - loss: 1.6607 - val_accuracy: 0.7168 - val_loss: 1.0977 - learning_rate: 1.0000e-04
# Epoch 15/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 78s 342ms/step - accuracy: 0.5809 - loss: 1.5789 - val_accuracy: 0.7245 - val_loss: 1.0208 - learning_rate: 1.0000e-04
# Epoch 16/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 78s 343ms/step - accuracy: 0.6035 - loss: 1.4886 - val_accuracy: 0.7437 - val_loss: 0.9866 - learning_rate: 1.0000e-04
# Epoch 17/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 344ms/step - accuracy: 0.6161 - loss: 1.4327 - val_accuracy: 0.7534 - val_loss: 0.9344 - learning_rate: 1.0000e-04
# Epoch 18/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 80s 349ms/step - accuracy: 0.6439 - loss: 1.3550 - val_accuracy: 0.7620 - val_loss: 0.8989 - learning_rate: 1.0000e-04
# Epoch 19/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 347ms/step - accuracy: 0.6516 - loss: 1.2780 - val_accuracy: 0.7592 - val_loss: 0.8676 - learning_rate: 1.0000e-04
# Epoch 20/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 346ms/step - accuracy: 0.6564 - loss: 1.2379 - val_accuracy: 0.7736 - val_loss: 0.8334 - learning_rate: 1.0000e-04
# Epoch 21/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 345ms/step - accuracy: 0.6789 - loss: 1.1814 - val_accuracy: 0.7823 - val_loss: 0.8104 - learning_rate: 1.0000e-04
# Epoch 22/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 78s 342ms/step - accuracy: 0.6978 - loss: 1.1357 - val_accuracy: 0.7678 - val_loss: 0.7753 - learning_rate: 1.0000e-04
# Epoch 23/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 78s 343ms/step - accuracy: 0.7113 - loss: 1.0600 - val_accuracy: 0.7852 - val_loss: 0.7546 - learning_rate: 1.0000e-04
# Epoch 24/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 345ms/step - accuracy: 0.7196 - loss: 1.0244 - val_accuracy: 0.7871 - val_loss: 0.7372 - learning_rate: 1.0000e-04
# Epoch 25/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 78s 342ms/step - accuracy: 0.7283 - loss: 0.9995 - val_accuracy: 0.7803 - val_loss: 0.7236 - learning_rate: 1.0000e-04
# Epoch 26/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 81s 354ms/step - accuracy: 0.7441 - loss: 0.9205 - val_accuracy: 0.7890 - val_loss: 0.7002 - learning_rate: 1.0000e-04
# Epoch 27/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 80s 348ms/step - accuracy: 0.7569 - loss: 0.9058 - val_accuracy: 0.7987 - val_loss: 0.6924 - learning_rate: 1.0000e-04
# Epoch 28/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 347ms/step - accuracy: 0.7663 - loss: 0.8490 - val_accuracy: 0.8006 - val_loss: 0.6628 - learning_rate: 1.0000e-04
# Epoch 29/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 78s 339ms/step - accuracy: 0.7724 - loss: 0.8092 - val_accuracy: 0.7938 - val_loss: 0.6657 - learning_rate: 1.0000e-04
# Epoch 30/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 344ms/step - accuracy: 0.7801 - loss: 0.7927 - val_accuracy: 0.8092 - val_loss: 0.6532 - learning_rate: 1.0000e-04
# Epoch 31/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 80s 348ms/step - accuracy: 0.7962 - loss: 0.7429 - val_accuracy: 0.8015 - val_loss: 0.6337 - learning_rate: 1.0000e-04
# Epoch 32/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 80s 351ms/step - accuracy: 0.7887 - loss: 0.7328 - val_accuracy: 0.8083 - val_loss: 0.6262 - learning_rate: 1.0000e-04
# Epoch 33/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 345ms/step - accuracy: 0.8023 - loss: 0.6985 - val_accuracy: 0.8160 - val_loss: 0.6297 - learning_rate: 1.0000e-04
# Epoch 34/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 78s 343ms/step - accuracy: 0.8096 - loss: 0.6728 - val_accuracy: 0.8276 - val_loss: 0.6111 - learning_rate: 1.0000e-04
# Epoch 35/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 345ms/step - accuracy: 0.8256 - loss: 0.6394 - val_accuracy: 0.8314 - val_loss: 0.6032 - learning_rate: 1.0000e-04
# Epoch 36/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 345ms/step - accuracy: 0.8247 - loss: 0.6111 - val_accuracy: 0.8170 - val_loss: 0.6277 - learning_rate: 1.0000e-04
# Epoch 37/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 78s 339ms/step - accuracy: 0.8372 - loss: 0.5819 - val_accuracy: 0.8237 - val_loss: 0.5945 - learning_rate: 1.0000e-04
# Epoch 38/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 78s 342ms/step - accuracy: 0.8360 - loss: 0.5671 - val_accuracy: 0.8170 - val_loss: 0.5881 - learning_rate: 1.0000e-04
# Epoch 39/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 345ms/step - accuracy: 0.8451 - loss: 0.5351 - val_accuracy: 0.8237 - val_loss: 0.5659 - learning_rate: 1.0000e-04
# Epoch 40/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 346ms/step - accuracy: 0.8480 - loss: 0.5220 - val_accuracy: 0.8247 - val_loss: 0.5903 - learning_rate: 1.0000e-04
# Epoch 41/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 80s 351ms/step - accuracy: 0.8559 - loss: 0.4985 - val_accuracy: 0.8266 - val_loss: 0.5811 - learning_rate: 1.0000e-04
# Epoch 42/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8632 - loss: 0.4872
# Epoch 42: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 80s 348ms/step - accuracy: 0.8617 - loss: 0.4782 - val_accuracy: 0.8247 - val_loss: 0.5685 - learning_rate: 1.0000e-04
# Epoch 43/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 346ms/step - accuracy: 0.8736 - loss: 0.4482 - val_accuracy: 0.8295 - val_loss: 0.5503 - learning_rate: 3.0000e-05
# Epoch 44/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 347ms/step - accuracy: 0.8777 - loss: 0.4321 - val_accuracy: 0.8353 - val_loss: 0.5498 - learning_rate: 3.0000e-05
# Epoch 45/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 345ms/step - accuracy: 0.8804 - loss: 0.4185 - val_accuracy: 0.8353 - val_loss: 0.5519 - learning_rate: 3.0000e-05
# Epoch 46/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 347ms/step - accuracy: 0.8813 - loss: 0.4142 - val_accuracy: 0.8401 - val_loss: 0.5394 - learning_rate: 3.0000e-05
# Epoch 47/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 80s 349ms/step - accuracy: 0.8810 - loss: 0.4151 - val_accuracy: 0.8372 - val_loss: 0.5404 - learning_rate: 3.0000e-05
# Epoch 48/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 346ms/step - accuracy: 0.8854 - loss: 0.4008 - val_accuracy: 0.8410 - val_loss: 0.5406 - learning_rate: 3.0000e-05
# Epoch 49/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.8864 - loss: 0.3901
# Epoch 49: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 79s 345ms/step - accuracy: 0.8868 - loss: 0.3884 - val_accuracy: 0.8333 - val_loss: 0.5430 - learning_rate: 3.0000e-05
# Epoch 50/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 80s 349ms/step - accuracy: 0.8874 - loss: 0.3763 - val_accuracy: 0.8382 - val_loss: 0.5393 - learning_rate: 9.0000e-06
# Restoring model weights from the end of the best epoch: 50.
#
# 50 épocas en 64.9 min

# %% [markdown]
# ## 5 · Curvas de entrenamiento

# %%
applyStyle()
import matplotlib.pyplot as plt

epocas = range(1, len(historia["loss"]) + 1)
figura, ejes = plt.subplots(1, 2, figsize=(11, 4.2))

ejes[0].plot(epocas, historia["accuracy"], color=SERIE_1, label="Entrenamiento")
ejes[0].plot(epocas, historia["val_accuracy"], color=SERIE_2, label="Validación")
ejes[0].set(title=f"{RUN_NAME} · Exactitud", xlabel="Época", ylim=(0, 1))
ejes[0].legend(loc="lower right")

ejes[1].plot(epocas, historia["loss"], color=SERIE_1, label="Entrenamiento")
ejes[1].plot(epocas, historia["val_loss"], color=SERIE_2, label="Validación")
ejes[1].set(title=f"{RUN_NAME} · Pérdida", xlabel="Época")
ejes[1].legend(loc="upper right")

figura.tight_layout()
figura.savefig(IMGS / "training_history.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 6 · Evaluación
#
# Dos conjuntos: `test` (20%, métrica principal) y `validate` (10%, el que
# monitorean los callbacks).

# %%
metricas = {
    "test": evalStats.evaluar(modelo, dsTest, clases),
    "validate": evalStats.evaluar(modelo, dsVal, clases),
}

pd.DataFrame([
    {k: round(v, 4) if isinstance(v, float) else v
     for k, v in m.items()
     if k in ("num_samples", "accuracy", "top3_accuracy",
              "macro_f1", "weighted_f1", "macro_precision", "macro_recall")}
    for m in metricas.values()
], index=list(metricas.keys()))
# Out:
# 2026-09-12 00:45:07.632209: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-09-12 00:45:13.788985: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
#           num_samples  accuracy  top3_accuracy  macro_precision  macro_recall  \
# test             2062    0.8463         0.9476           0.8495        0.8473
# validate         1038    0.8382         0.9489           0.8451        0.8401
#
#           macro_f1  weighted_f1
# test        0.8426       0.8453
# validate    0.8369       0.8364

# %% [markdown]
# ## 7 · Matriz de confusión

# %%
_ = plotConfusionMatrix(
    metricas["test"],
    f"Matriz de confusión · prueba · {RUN_NAME}",
)
plt.savefig(IMGS / "confusion_test.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 8 · Confusiones principales

# %%
confusiones = evalStats.confusionesPrincipales(metricas["test"])
pd.DataFrame(confusiones).head(10)
# Out:
#                       real                    predicha  casos   tasa
# 0       parides_erithalion           parides_eurimedes     11  0.407
# 1           urbanus_procne          urbanus_simplicius     11  0.367
# 2      mechanitis_lysimnia          mechanitis_menapis     11  0.344
# 3            eurema_arbela          eurema_xantochlora      9  0.375
# 4     heliconius_melpomene            heliconius_erato      7  0.241
# 5         hamadryas_februa           hamadryas_feronia      5  0.192
# 6  archaeoprepona_demophon  archaeoprepona_amphimachus      5  0.172
# 7           urbanus_procne              urbanus_teleus      5  0.167
# 8            eurema_albula               ascia_monuste      5  0.161
# 9           urbanus_teleus              urbanus_procne      5  0.161

# %% [markdown]
# ## 9 · Versionado

# %%
modelo.save(RUN_DIR / "model.keras")
registro.writeJson(RUN_DIR / "history.json", historia)
registro.writeJson(RUN_DIR / "metrics.json", {
    "run_id": RUN_ID,
    "class_names": clases,
    "splits": metricas,
    "top_confusions": {
        s: evalStats.confusionesPrincipales(m) for s, m in metricas.items()
    },
})

configuracion = {
    "run_id": RUN_ID,
    "name": RUN_NAME,
    "architecture": ARQUITECTURA,
    "role": ROL,
    "notes": NOTAS,
    "num_classes": len(clases),
    "hyperparameters": {
        "img_size": list(TAMANO),
        "batch_size": LOTE,
        "epochs_budget": EPOCAS,
        "epochs_ran": len(historia["loss"]),
        "learning_rate": TASA_APRENDIZAJE,
        "early_stopping_patience": PACIENCIA,
        "class_weights": "balanced",
        "seed": SEMILLA,
        "finetuning": FRACCION_DESCONGELADA,
        "backbone": f"{ARQUITECTURA}/imagenet",
    },
    "environment": {
        "python": platform.python_version(),
        "tensorflow": tf.__version__,
        "platform": platform.platform(),
    },
    "started_at": inicio.isoformat(),
    "finished_at": fin.isoformat(),
    "training_minutes": round((fin - inicio).total_seconds() / 60, 1),
}
registro.writeJson(RUN_DIR / "run.json", configuracion)

registro.registerRun({
    "run_id": RUN_ID,
    "name": RUN_NAME,
    "architecture": ARQUITECTURA,
    "role": ROL,
    "finetuning": FRACCION_DESCONGELADA,
    "num_classes": len(clases),
    "epochs_ran": len(historia["loss"]),
    "training_minutes": configuracion["training_minutes"],
    "test_accuracy": metricas["test"]["accuracy"],
    "test_macro_f1": metricas["test"]["macro_f1"],
    "validate_accuracy": metricas["validate"]["accuracy"],
    "validate_macro_f1": metricas["validate"]["macro_f1"],
    "notes": NOTAS,
    "created_at": inicio.isoformat(),
})

if PROMOVER:
    registro.promoteRun(RUN_ID)

print(f"Run guardado en {RUN_DIR}")
# Out:
# Run guardado en /Users/cristiansandoval/Universidad/Semillero/ButterflyModeling/outputs/runs/20260912T044001Z_mobilenet-v3-small

# %% [markdown]
# ## Resumen

# %%
pd.Series({
    "run_id": RUN_ID,
    "arquitectura": ARQUITECTURA,
    "clases": len(clases),
    "epocas": len(historia["loss"]),
    "minutos": configuracion["training_minutes"],
    "test_accuracy": round(metricas["test"]["accuracy"], 4),
    "test_top3": round(metricas["test"]["top3_accuracy"], 4),
    "test_macro_f1": round(metricas["test"]["macro_f1"], 4),
    "validate_accuracy": round(metricas["validate"]["accuracy"], 4),
    "validate_macro_f1": round(metricas["validate"]["macro_f1"], 4),
}).to_frame("valor")
# Out:
#                                                  valor
# run_id             20260912T044001Z_mobilenet-v3-small
# arquitectura                        mobilenet_v3_small
# clases                                              79
# epocas                                              50
# minutos                                           64.9
# test_accuracy                                   0.8463
# test_top3                                       0.9476
# test_macro_f1                                   0.8426
# validate_accuracy                               0.8382
# validate_macro_f1                               0.8369
