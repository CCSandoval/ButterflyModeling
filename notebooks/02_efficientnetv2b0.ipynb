# %% [markdown]
# # 02 · EfficientNetV2B0 (transfer learning 2/5)
#
# Misma arquitectura de cabeza y mismo régimen de entrenamiento que `01_mobilenet.ipynb`, cambiando solo el backbone. EfficientNetV2B0 es la referencia moderna de mejor tradeoff accuracy/parámetros entre las 5 arquitecturas comparadas.

# %%
import os
from pathlib import Path

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
    os.chdir(ROOT)

print("Raíz del proyecto:", ROOT)
# Out:
# Raíz del proyecto: /Users/cristiansandoval/Universidad/Semillero/ButterflyModeling

# %%
import platform
from datetime import datetime, timezone

import numpy as np
import pandas as pd
import tensorflow as tf

from scripts import corpus, evalStats
from scripts import modelRegistry as registro
from scripts.architectures import buildModel, preprocessFn
from scripts.dataPipeline import buildAugmenter, loadSplit, preparar
from scripts.vizStyle import SERIE_1, SERIE_2, applyStyle, plotConfusionMatrix

ARQUITECTURA = "efficientnet_v2_b0"
RUN_NAME = "efficientnet-v2-b0"
NOTAS = "Transfer learning: EfficientNetV2B0 congelado + la misma cabeza del baseline"
PROMOVER = False

TAMANO = (320, 320)
LOTE = 32
EPOCAS = 50
PACIENCIA = 8
TASA_APRENDIZAJE = 1e-3
SEMILLA = 42

tf.keras.utils.set_random_seed(SEMILLA)
corpus.materializar()

RUN_ID = registro.buildRunId(RUN_NAME)
RUN_DIR = registro.createRunDir(RUN_ID)
IMGS = RUN_DIR / "imgs"

print(f"run_id : {RUN_ID}")
print(f"TF     : {tf.__version__} · dispositivos: "
      f"{[d.device_type for d in tf.config.list_physical_devices()]}")
# Out:
# run_id : 20260902T015532Z_efficientnet-v2-b0
# TF     : 2.19.1 · dispositivos: ['CPU']

# %% [markdown]
# ## 1 · Datos
#
# Un tf.data.Dataset por split. Solo `train` se aumenta; `validate`/`test` son
# deterministas (`shuffle=False`, indispensable para que `y_true` se alinee con
# las predicciones).

# %%
preprocess = preprocessFn(ARQUITECTURA)
augmentador = buildAugmenter()

dsTrainCrudo, clases = loadSplit("dataset/train", TAMANO, LOTE)
dsValCrudo, _ = loadSplit("dataset/validate", TAMANO, LOTE, shuffle=False)
dsTestCrudo, _ = loadSplit("dataset/test", TAMANO, LOTE, shuffle=False)

dsTrain = preparar(dsTrainCrudo, preprocess, augmentador)
dsVal = preparar(dsValCrudo, preprocess)
dsTest = preparar(dsTestCrudo, preprocess)

print(f"{len(clases)} clases")
# Out:
# Found 7218 files belonging to 79 classes.
# Found 1038 files belonging to 79 classes.
# Found 2062 files belonging to 79 classes.
# 79 clases

# %% [markdown]
# ## 2 · Modelo

# %%
modelo = buildModel(ARQUITECTURA, len(clases))

entrenables = sum(int(np.prod(w.shape)) for w in modelo.trainable_weights)
congelados = sum(int(np.prod(w.shape)) for w in modelo.non_trainable_weights)
pd.Series({
    "parametros_totales": modelo.count_params(),
    "entrenables": entrenables,
    "congelados": congelados,
    "clases_salida": len(clases),
}).to_frame("valor")
# Out:
#                       valor
# parametros_totales  6753183
# entrenables          832079
# congelados          5921104
# clases_salida            79

# %% [markdown]
# ## 3 · Pesos de clase

# %%
pesosClase = corpus.classWeights()
pd.Series(
    {clases[i]: round(p, 3) for i, p in pesosClase.items()}
).sort_values(ascending=False).head(8).to_frame("peso")
# Out:
#                        peso
# autochton_itylus      3.151
# taygetis_sylvia       3.151
# cissia_confusa        3.151
# pseudodebis_puritana  3.046
# pyrgus_adepta         2.947
# pteronymia_latilla    2.125
# euselasia_mys         2.077
# pteronymia_aletta     1.986

# %% [markdown]
# ## 4 · Entrenamiento

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

modelo.compile(
    loss="categorical_crossentropy",
    optimizer=Adam(learning_rate=TASA_APRENDIZAJE),
    metrics=["accuracy"],
)

callbacks = [
    EarlyStopping(monitor="val_loss", patience=PACIENCIA,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3,
                       min_lr=1e-6, verbose=1),
]

inicio = datetime.now(timezone.utc)
ajuste = modelo.fit(
    dsTrain,
    validation_data=dsVal,
    epochs=EPOCAS,
    callbacks=callbacks,
    class_weight=pesosClase,
)
fin = datetime.now(timezone.utc)

historia = {k: [float(v) for v in vs] for k, vs in ajuste.history.items()}
print(f"\n{len(historia['loss'])} épocas en {(fin - inicio).total_seconds() / 60:.1f} min")
# Out:
# Epoch 1/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 218s 943ms/step - accuracy: 0.1018 - loss: 4.0543 - val_accuracy: 0.3420 - val_loss: 2.6698 - learning_rate: 0.0010
# Epoch 2/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 0.2646 - loss: 2.7931 - val_accuracy: 0.5077 - val_loss: 1.8394 - learning_rate: 0.0010
# Epoch 3/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.3685 - loss: 2.2947 - val_accuracy: 0.5588 - val_loss: 1.5284 - learning_rate: 0.0010
# Epoch 4/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 267s 1s/step - accuracy: 0.4417 - loss: 1.9861 - val_accuracy: 0.6098 - val_loss: 1.3121 - learning_rate: 0.0010
# Epoch 5/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.4738 - loss: 1.8402 - val_accuracy: 0.6455 - val_loss: 1.2106 - learning_rate: 0.0010
# Epoch 6/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - accuracy: 0.5068 - loss: 1.7134 - val_accuracy: 0.6686 - val_loss: 1.1064 - learning_rate: 0.0010
# Epoch 7/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 323s 1s/step - accuracy: 0.5241 - loss: 1.6149 - val_accuracy: 0.6888 - val_loss: 1.0181 - learning_rate: 0.0010
# Epoch 8/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 325s 1s/step - accuracy: 0.5472 - loss: 1.5221 - val_accuracy: 0.7033 - val_loss: 0.9427 - learning_rate: 0.0010
# Epoch 9/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 253s 1s/step - accuracy: 0.5658 - loss: 1.4632 - val_accuracy: 0.7042 - val_loss: 0.9082 - learning_rate: 0.0010
# Epoch 10/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 243s 1s/step - accuracy: 0.5768 - loss: 1.4189 - val_accuracy: 0.7322 - val_loss: 0.8506 - learning_rate: 0.0010
# Epoch 11/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 250s 1s/step - accuracy: 0.5867 - loss: 1.3628 - val_accuracy: 0.7177 - val_loss: 0.8522 - learning_rate: 0.0010
# Epoch 12/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.5955 - loss: 1.3310 - val_accuracy: 0.7187 - val_loss: 0.8456 - learning_rate: 0.0010
# Epoch 13/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.6161 - loss: 1.2733 - val_accuracy: 0.7360 - val_loss: 0.8289 - learning_rate: 0.0010
# Epoch 14/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 276s 1s/step - accuracy: 0.6207 - loss: 1.2572 - val_accuracy: 0.7158 - val_loss: 0.8669 - learning_rate: 0.0010
# Epoch 15/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 285s 1s/step - accuracy: 0.6237 - loss: 1.2624 - val_accuracy: 0.7649 - val_loss: 0.7561 - learning_rate: 0.0010
# Epoch 16/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 279s 1s/step - accuracy: 0.6366 - loss: 1.2035 - val_accuracy: 0.7514 - val_loss: 0.7580 - learning_rate: 0.0010
# Epoch 17/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 280s 1s/step - accuracy: 0.6383 - loss: 1.1973 - val_accuracy: 0.7563 - val_loss: 0.7615 - learning_rate: 0.0010
# Epoch 18/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6369 - loss: 1.1892
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 281s 1s/step - accuracy: 0.6442 - loss: 1.1631 - val_accuracy: 0.7437 - val_loss: 0.7859 - learning_rate: 0.0010
# Epoch 19/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 282s 1s/step - accuracy: 0.6667 - loss: 1.0616 - val_accuracy: 0.7707 - val_loss: 0.7085 - learning_rate: 3.0000e-04
# Epoch 20/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 282s 1s/step - accuracy: 0.6822 - loss: 1.0031 - val_accuracy: 0.7755 - val_loss: 0.6847 - learning_rate: 3.0000e-04
# Epoch 21/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 280s 1s/step - accuracy: 0.7037 - loss: 0.9649 - val_accuracy: 0.7765 - val_loss: 0.6833 - learning_rate: 3.0000e-04
# Epoch 22/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 283s 1s/step - accuracy: 0.6959 - loss: 0.9974 - val_accuracy: 0.7919 - val_loss: 0.6671 - learning_rate: 3.0000e-04
# Epoch 23/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - accuracy: 0.7035 - loss: 0.9461 - val_accuracy: 0.7967 - val_loss: 0.6431 - learning_rate: 3.0000e-04
# Epoch 24/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.7134 - loss: 0.9081 - val_accuracy: 0.7909 - val_loss: 0.6469 - learning_rate: 3.0000e-04
# Epoch 25/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 267s 1s/step - accuracy: 0.7084 - loss: 0.9450 - val_accuracy: 0.7967 - val_loss: 0.6446 - learning_rate: 3.0000e-04
# Epoch 26/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 275s 1s/step - accuracy: 0.7207 - loss: 0.8927 - val_accuracy: 0.8015 - val_loss: 0.6314 - learning_rate: 3.0000e-04
# Epoch 27/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.7286 - loss: 0.8837 - val_accuracy: 0.8025 - val_loss: 0.6428 - learning_rate: 3.0000e-04
# Epoch 28/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.7260 - loss: 0.8757 - val_accuracy: 0.7996 - val_loss: 0.6365 - learning_rate: 3.0000e-04
# Epoch 29/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - accuracy: 0.7383 - loss: 0.8395 - val_accuracy: 0.7977 - val_loss: 0.6256 - learning_rate: 3.0000e-04
# Epoch 30/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.7340 - loss: 0.8525 - val_accuracy: 0.8025 - val_loss: 0.6253 - learning_rate: 3.0000e-04
# Epoch 31/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - accuracy: 0.7391 - loss: 0.8373 - val_accuracy: 0.8035 - val_loss: 0.6047 - learning_rate: 3.0000e-04
# Epoch 32/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.7434 - loss: 0.8295 - val_accuracy: 0.8102 - val_loss: 0.5973 - learning_rate: 3.0000e-04
# Epoch 33/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.7409 - loss: 0.8141 - val_accuracy: 0.8170 - val_loss: 0.5859 - learning_rate: 3.0000e-04
# Epoch 34/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.7456 - loss: 0.7967 - val_accuracy: 0.8064 - val_loss: 0.5919 - learning_rate: 3.0000e-04
# Epoch 35/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - accuracy: 0.7444 - loss: 0.8130 - val_accuracy: 0.8054 - val_loss: 0.6031 - learning_rate: 3.0000e-04
# Epoch 36/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7411 - loss: 0.7941
# Epoch 36: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.7441 - loss: 0.7847 - val_accuracy: 0.8044 - val_loss: 0.6155 - learning_rate: 3.0000e-04
# Epoch 37/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 0.7533 - loss: 0.7821 - val_accuracy: 0.8092 - val_loss: 0.5987 - learning_rate: 9.0000e-05
# Epoch 38/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - accuracy: 0.7519 - loss: 0.7518 - val_accuracy: 0.8092 - val_loss: 0.5992 - learning_rate: 9.0000e-05
# Epoch 39/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7635 - loss: 0.7447
# Epoch 39: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.7625 - loss: 0.7490 - val_accuracy: 0.8121 - val_loss: 0.5949 - learning_rate: 9.0000e-05
# Epoch 40/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 267s 1s/step - accuracy: 0.7632 - loss: 0.7528 - val_accuracy: 0.8150 - val_loss: 0.5917 - learning_rate: 2.7000e-05
# Epoch 41/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - accuracy: 0.7660 - loss: 0.7399 - val_accuracy: 0.8121 - val_loss: 0.5906 - learning_rate: 2.7000e-05
# Epoch 41: early stopping
# Restoring model weights from the end of the best epoch: 33.
#
# 41 épocas en 183.6 min

# %% [markdown]
# ## 5 · Curvas de entrenamiento

# %%
applyStyle()
import matplotlib.pyplot as plt

epocas = range(1, len(historia["loss"]) + 1)
figura, ejes = plt.subplots(1, 2, figsize=(11, 4.2))

ejes[0].plot(epocas, historia["accuracy"], color=SERIE_1, label="Entrenamiento")
ejes[0].plot(epocas, historia["val_accuracy"], color=SERIE_2, label="Validación")
ejes[0].set(title=f"{RUN_NAME} · Exactitud", xlabel="Época", ylim=(0, 1))
ejes[0].legend(loc="lower right")

ejes[1].plot(epocas, historia["loss"], color=SERIE_1, label="Entrenamiento")
ejes[1].plot(epocas, historia["val_loss"], color=SERIE_2, label="Validación")
ejes[1].set(title=f"{RUN_NAME} · Pérdida", xlabel="Época")
ejes[1].legend(loc="upper right")

figura.tight_layout()
figura.savefig(IMGS / "training_history.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 6 · Evaluación
#
# Dos conjuntos: `test` (20%, métrica principal) y `validate` (10%, el que
# monitorean los callbacks).

# %%
metricas = {
    "test": evalStats.evaluar(modelo, dsTest, clases),
    "validate": evalStats.evaluar(modelo, dsVal, clases),
}

pd.DataFrame([
    {k: round(v, 4) if isinstance(v, float) else v
     for k, v in m.items()
     if k in ("num_samples", "accuracy", "top3_accuracy",
              "macro_f1", "weighted_f1", "macro_precision", "macro_recall")}
    for m in metricas.values()
], index=list(metricas.keys()))
# Out:
# 2026-09-02 00:00:10.233322: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-09-02 00:00:38.331444: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
#           num_samples  accuracy  top3_accuracy  macro_precision  macro_recall  \
# test             2062    0.8143         0.9520           0.8090        0.8127
# validate         1038    0.8170         0.9566           0.8312        0.8172
#
#           macro_f1  weighted_f1
# test        0.8020       0.8113
# validate    0.8137       0.8156

# %% [markdown]
# ## 7 · Matriz de confusión

# %%
_ = plotConfusionMatrix(
    metricas["test"],
    f"Matriz de confusión · prueba · {RUN_NAME}",
)
plt.savefig(IMGS / "confusion_test.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 8 · Confusiones principales

# %%
confusiones = evalStats.confusionesPrincipales(metricas["test"])
pd.DataFrame(confusiones).head(10)
# Out:
#                       real                    predicha  casos   tasa
# 0            eurema_arbela              phoebis_sennae     11  0.458
# 1           urbanus_procne          urbanus_simplicius     11  0.367
# 2      mechanitis_lysimnia          mechanitis_menapis     10  0.312
# 3     heliconius_melpomene            heliconius_erato      9  0.310
# 4           urbanus_teleus              urbanus_procne      9  0.290
# 5           urbanus_teleus          urbanus_simplicius      9  0.290
# 6            eurema_albula               ascia_monuste      8  0.258
# 7       eurema_xantochlora               eurema_arbela      6  0.273
# 8         hamadryas_februa           hamadryas_feronia      6  0.231
# 9  archaeoprepona_demophon  archaeoprepona_amphimachus      6  0.207

# %% [markdown]
# ## 9 · Versionado

# %%
modelo.save(RUN_DIR / "model.keras")
registro.writeJson(RUN_DIR / "history.json", historia)
registro.writeJson(RUN_DIR / "metrics.json", {
    "run_id": RUN_ID,
    "class_names": clases,
    "splits": metricas,
    "top_confusions": {
        s: evalStats.confusionesPrincipales(m) for s, m in metricas.items()
    },
})

configuracion = {
    "run_id": RUN_ID,
    "name": RUN_NAME,
    "architecture": ARQUITECTURA,
    "notes": NOTAS,
    "num_classes": len(clases),
    "hyperparameters": {
        "img_size": list(TAMANO),
        "batch_size": LOTE,
        "epochs_budget": EPOCAS,
        "epochs_ran": len(historia["loss"]),
        "learning_rate": TASA_APRENDIZAJE,
        "early_stopping_patience": PACIENCIA,
        "class_weights": "balanced",
        "seed": SEMILLA,
        "backbone": f"{ARQUITECTURA}/imagenet (congelado)",
    },
    "environment": {
        "python": platform.python_version(),
        "tensorflow": tf.__version__,
        "platform": platform.platform(),
    },
    "started_at": inicio.isoformat(),
    "finished_at": fin.isoformat(),
    "training_minutes": round((fin - inicio).total_seconds() / 60, 1),
}
registro.writeJson(RUN_DIR / "run.json", configuracion)

registro.registerRun({
    "run_id": RUN_ID,
    "name": RUN_NAME,
    "architecture": ARQUITECTURA,
    "num_classes": len(clases),
    "epochs_ran": len(historia["loss"]),
    "training_minutes": configuracion["training_minutes"],
    "test_accuracy": metricas["test"]["accuracy"],
    "test_macro_f1": metricas["test"]["macro_f1"],
    "validate_accuracy": metricas["validate"]["accuracy"],
    "validate_macro_f1": metricas["validate"]["macro_f1"],
    "notes": NOTAS,
    "created_at": inicio.isoformat(),
})

if PROMOVER:
    registro.promoteRun(RUN_ID)

print(f"Run guardado en {RUN_DIR}")
# Out:
# Run guardado en /Users/cristiansandoval/Universidad/Semillero/ButterflyModeling/outputs/runs/20260902T015532Z_efficientnet-v2-b0

# %% [markdown]
# ## Resumen

# %%
pd.Series({
    "run_id": RUN_ID,
    "arquitectura": ARQUITECTURA,
    "clases": len(clases),
    "epocas": len(historia["loss"]),
    "minutos": configuracion["training_minutes"],
    "test_accuracy": round(metricas["test"]["accuracy"], 4),
    "test_top3": round(metricas["test"]["top3_accuracy"], 4),
    "test_macro_f1": round(metricas["test"]["macro_f1"], 4),
    "validate_accuracy": round(metricas["validate"]["accuracy"], 4),
    "validate_macro_f1": round(metricas["validate"]["macro_f1"], 4),
}).to_frame("valor")
# Out:
#                                                  valor
# run_id             20260902T015532Z_efficientnet-v2-b0
# arquitectura                        efficientnet_v2_b0
# clases                                              79
# epocas                                              41
# minutos                                          183.6
# test_accuracy                                   0.8143
# test_top3                                        0.952
# test_macro_f1                                    0.802
# validate_accuracy                                0.817
# validate_macro_f1                               0.8137
