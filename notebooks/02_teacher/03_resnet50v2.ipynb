# %% [markdown]
# # 03 · ResNet50V2
#
# Candidato a docente. 24.8M parámetros, 127 ms/imagen.

# %%
import os
import sys
from pathlib import Path

ROOT = Path.cwd()
while not (ROOT / "corpus.json").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print("Raíz del proyecto:", ROOT)
# Out:
# Raíz del proyecto: /Users/cristiansandoval/Universidad/Semillero/ButterflyModeling

# %%
import platform
from datetime import datetime, timezone

import numpy as np
import pandas as pd
import tensorflow as tf

from scripts import corpus, evalStats
from scripts import modelRegistry as registro
from scripts.architectures import buildModel, descongelarCola, preprocessFn
from scripts.dataPipeline import buildAugmenter, loadSplit, preparar
from scripts.vizStyle import SERIE_1, SERIE_2, applyStyle, plotConfusionMatrix

ARQUITECTURA = "resnet50_v2"
RUN_NAME = "resnet50-v2"
NOTAS = "Candidato a docente: ResNet50V2 + cabeza comun"
ROL = "docente"
PROMOVER = False

# 0.0 reproduce el run con backbone congelado; 0.30 descongela la cola
FRACCION_DESCONGELADA = 0.30

TAMANO = (320, 320)
LOTE = 32
EPOCAS = 50
PACIENCIA = 8
TASA_APRENDIZAJE = 1e-4 if FRACCION_DESCONGELADA else 1e-3
SEMILLA = 42

tf.keras.utils.set_random_seed(SEMILLA)
corpus.materializar()

RUN_ID = registro.buildRunId(RUN_NAME)
RUN_DIR = registro.createRunDir(RUN_ID)
IMGS = RUN_DIR / "imgs"

print(f"run_id : {RUN_ID}")
print(f"TF     : {tf.__version__} · dispositivos: "
      f"{[d.device_type for d in tf.config.list_physical_devices()]}")
# Out:
# run_id : 20260913T104733Z_resnet50-v2
# TF     : 2.19.1 · dispositivos: ['CPU']

# %% [markdown]
# ## 1 · Datos
#
# Un tf.data.Dataset por split. Solo `train` se aumenta; `validate`/`test` son
# deterministas (`shuffle=False`, indispensable para que `y_true` se alinee con
# las predicciones).

# %%
preprocess = preprocessFn(ARQUITECTURA)
augmentador = buildAugmenter()

dsTrainCrudo, clases = loadSplit("dataset/train", TAMANO, LOTE)
dsValCrudo, _ = loadSplit("dataset/validate", TAMANO, LOTE, shuffle=False)
dsTestCrudo, _ = loadSplit("dataset/test", TAMANO, LOTE, shuffle=False)

dsTrain = preparar(dsTrainCrudo, preprocess, augmentador)
dsVal = preparar(dsValCrudo, preprocess)
dsTest = preparar(dsTestCrudo, preprocess)

print(f"{len(clases)} clases")
# Out:
# Found 7218 files belonging to 79 classes.
# Found 1038 files belonging to 79 classes.
# Found 2062 files belonging to 79 classes.
# 79 clases

# %% [markdown]
# ## 2 · Modelo

# %%
modelo = buildModel(ARQUITECTURA, len(clases))
if FRACCION_DESCONGELADA:
    print(descongelarCola(modelo, FRACCION_DESCONGELADA))

entrenables = sum(int(np.prod(w.shape)) for w in modelo.trainable_weights)
congelados = sum(int(np.prod(w.shape)) for w in modelo.non_trainable_weights)
pd.Series({
    "parametros_totales": modelo.count_params(),
    "entrenables": entrenables,
    "congelados": congelados,
    "clases_salida": len(clases),
}).to_frame("valor")
# Out:
# {'capas_backbone': 190, 'capas_descongeladas': 42, 'parametros_entrenables': 18405967}
#                        valor
# parametros_totales  24791887
# entrenables         18405967
# congelados           6385920
# clases_salida             79

# %% [markdown]
# ## 3 · Pesos de clase

# %%
pesosClase = corpus.classWeights()
pd.Series(
    {clases[i]: round(p, 3) for i, p in pesosClase.items()}
).sort_values(ascending=False).head(8).to_frame("peso")
# Out:
#                        peso
# autochton_itylus      3.151
# taygetis_sylvia       3.151
# cissia_confusa        3.151
# pseudodebis_puritana  3.046
# pyrgus_adepta         2.947
# pteronymia_latilla    2.125
# euselasia_mys         2.077
# pteronymia_aletta     1.986

# %% [markdown]
# ## 4 · Entrenamiento

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

modelo.compile(
    loss="categorical_crossentropy",
    optimizer=Adam(learning_rate=TASA_APRENDIZAJE),
    metrics=["accuracy"],
)

callbacks = [
    EarlyStopping(monitor="val_loss", patience=PACIENCIA,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3,
                       min_lr=1e-6, verbose=1),
]

inicio = datetime.now(timezone.utc)
ajuste = modelo.fit(
    dsTrain,
    validation_data=dsVal,
    epochs=EPOCAS,
    callbacks=callbacks,
    class_weight=pesosClase,
)
fin = datetime.now(timezone.utc)

historia = {k: [float(v) for v in vs] for k, vs in ajuste.history.items()}
print(f"\n{len(historia['loss'])} épocas en {(fin - inicio).total_seconds() / 60:.1f} min")
# Out:
# Epoch 1/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 772s 3s/step - accuracy: 0.0165 - loss: 5.3433 - val_accuracy: 0.0087 - val_loss: 6.3703 - learning_rate: 1.0000e-04
# Epoch 2/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 862s 4s/step - accuracy: 0.0163 - loss: 5.2316 - val_accuracy: 0.0173 - val_loss: 6.4958 - learning_rate: 1.0000e-04
# Epoch 3/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 867s 4s/step - accuracy: 0.0216 - loss: 4.9792 - val_accuracy: 0.0212 - val_loss: 4.8425 - learning_rate: 1.0000e-04
# Epoch 4/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 876s 4s/step - accuracy: 0.0259 - loss: 4.7388 - val_accuracy: 0.0482 - val_loss: 4.0489 - learning_rate: 1.0000e-04
# Epoch 5/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 885s 4s/step - accuracy: 0.0238 - loss: 4.6632 - val_accuracy: 0.0395 - val_loss: 4.0756 - learning_rate: 1.0000e-04
# Epoch 6/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 882s 4s/step - accuracy: 0.0309 - loss: 4.5397 - val_accuracy: 0.0376 - val_loss: 4.0550 - learning_rate: 1.0000e-04
# Epoch 7/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 879s 4s/step - accuracy: 0.0338 - loss: 4.4463 - val_accuracy: 0.0453 - val_loss: 3.8863 - learning_rate: 1.0000e-04
# Epoch 8/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 880s 4s/step - accuracy: 0.0328 - loss: 4.3621 - val_accuracy: 0.0453 - val_loss: 3.8479 - learning_rate: 1.0000e-04
# Epoch 9/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 891s 4s/step - accuracy: 0.0357 - loss: 4.2860 - val_accuracy: 0.0424 - val_loss: 3.8108 - learning_rate: 1.0000e-04
# Epoch 10/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 890s 4s/step - accuracy: 0.0375 - loss: 4.2620 - val_accuracy: 0.0549 - val_loss: 3.7762 - learning_rate: 1.0000e-04
# Epoch 11/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 890s 4s/step - accuracy: 0.0356 - loss: 4.2079 - val_accuracy: 0.0347 - val_loss: 3.8857 - learning_rate: 1.0000e-04
# Epoch 12/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 906s 4s/step - accuracy: 0.0399 - loss: 4.1517 - val_accuracy: 0.0549 - val_loss: 3.7049 - learning_rate: 1.0000e-04
# Epoch 13/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 889s 4s/step - accuracy: 0.0389 - loss: 4.1696 - val_accuracy: 0.0145 - val_loss: 4.8222 - learning_rate: 1.0000e-04
# Epoch 14/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 889s 4s/step - accuracy: 0.0406 - loss: 4.1105 - val_accuracy: 0.0318 - val_loss: 3.9147 - learning_rate: 1.0000e-04
# Epoch 15/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.0431 - loss: 4.0664
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 885s 4s/step - accuracy: 0.0427 - loss: 4.0589 - val_accuracy: 0.0366 - val_loss: 3.9171 - learning_rate: 1.0000e-04
# Epoch 16/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 896s 4s/step - accuracy: 0.0400 - loss: 4.0205 - val_accuracy: 0.0520 - val_loss: 3.6487 - learning_rate: 3.0000e-05
# Epoch 17/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 903s 4s/step - accuracy: 0.0413 - loss: 4.0114 - val_accuracy: 0.0414 - val_loss: 3.6995 - learning_rate: 3.0000e-05
# Epoch 18/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 899s 4s/step - accuracy: 0.0400 - loss: 3.9986 - val_accuracy: 0.0655 - val_loss: 3.6160 - learning_rate: 3.0000e-05
# Epoch 19/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 896s 4s/step - accuracy: 0.0393 - loss: 3.9849 - val_accuracy: 0.0530 - val_loss: 3.5982 - learning_rate: 3.0000e-05
# Epoch 20/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 898s 4s/step - accuracy: 0.0387 - loss: 4.0096 - val_accuracy: 0.0511 - val_loss: 3.5869 - learning_rate: 3.0000e-05
# Epoch 21/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 922s 4s/step - accuracy: 0.0457 - loss: 3.9359 - val_accuracy: 0.0530 - val_loss: 3.6268 - learning_rate: 3.0000e-05
# Epoch 22/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 932s 4s/step - accuracy: 0.0427 - loss: 3.9622 - val_accuracy: 0.0539 - val_loss: 3.5575 - learning_rate: 3.0000e-05
# Epoch 23/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 932s 4s/step - accuracy: 0.0427 - loss: 3.9410 - val_accuracy: 0.0501 - val_loss: 3.6525 - learning_rate: 3.0000e-05
# Epoch 24/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 936s 4s/step - accuracy: 0.0447 - loss: 3.9186 - val_accuracy: 0.0645 - val_loss: 3.6078 - learning_rate: 3.0000e-05
# Epoch 25/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.0421 - loss: 3.9130
# Epoch 25: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 928s 4s/step - accuracy: 0.0447 - loss: 3.9145 - val_accuracy: 0.0414 - val_loss: 3.9799 - learning_rate: 3.0000e-05
# Epoch 26/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 930s 4s/step - accuracy: 0.0435 - loss: 3.8941 - val_accuracy: 0.0559 - val_loss: 3.5787 - learning_rate: 9.0000e-06
# Epoch 27/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 921s 4s/step - accuracy: 0.0453 - loss: 3.8607 - val_accuracy: 0.0578 - val_loss: 3.5437 - learning_rate: 9.0000e-06
# Epoch 28/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 914s 4s/step - accuracy: 0.0438 - loss: 3.8761 - val_accuracy: 0.0588 - val_loss: 3.5625 - learning_rate: 9.0000e-06
# Epoch 29/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 918s 4s/step - accuracy: 0.0442 - loss: 3.8700 - val_accuracy: 0.0549 - val_loss: 3.5818 - learning_rate: 9.0000e-06
# Epoch 30/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 920s 4s/step - accuracy: 0.0493 - loss: 3.8595 - val_accuracy: 0.0703 - val_loss: 3.4745 - learning_rate: 9.0000e-06
# Epoch 31/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 927s 4s/step - accuracy: 0.0500 - loss: 3.8226 - val_accuracy: 0.0655 - val_loss: 3.5273 - learning_rate: 9.0000e-06
# Epoch 32/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 928s 4s/step - accuracy: 0.0495 - loss: 3.8491 - val_accuracy: 0.0732 - val_loss: 3.4771 - learning_rate: 9.0000e-06
# Epoch 33/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.0541 - loss: 3.8064
# Epoch 33: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 936s 4s/step - accuracy: 0.0503 - loss: 3.8265 - val_accuracy: 0.0674 - val_loss: 3.4865 - learning_rate: 9.0000e-06
# Epoch 34/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 953s 4s/step - accuracy: 0.0524 - loss: 3.8309 - val_accuracy: 0.0800 - val_loss: 3.4440 - learning_rate: 2.7000e-06
# Epoch 35/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 956s 4s/step - accuracy: 0.0502 - loss: 3.8146 - val_accuracy: 0.0761 - val_loss: 3.4339 - learning_rate: 2.7000e-06
# Epoch 36/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 955s 4s/step - accuracy: 0.0445 - loss: 3.8223 - val_accuracy: 0.0800 - val_loss: 3.4362 - learning_rate: 2.7000e-06
# Epoch 37/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 958s 4s/step - accuracy: 0.0446 - loss: 3.8312 - val_accuracy: 0.0800 - val_loss: 3.4277 - learning_rate: 2.7000e-06
# Epoch 38/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 965s 4s/step - accuracy: 0.0510 - loss: 3.8087 - val_accuracy: 0.0809 - val_loss: 3.4264 - learning_rate: 2.7000e-06
# Epoch 39/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 956s 4s/step - accuracy: 0.0540 - loss: 3.8212 - val_accuracy: 0.0829 - val_loss: 3.4432 - learning_rate: 2.7000e-06
# Epoch 40/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 951s 4s/step - accuracy: 0.0497 - loss: 3.8190 - val_accuracy: 0.0771 - val_loss: 3.4426 - learning_rate: 2.7000e-06
# Epoch 41/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 956s 4s/step - accuracy: 0.0572 - loss: 3.8063 - val_accuracy: 0.0751 - val_loss: 3.4194 - learning_rate: 2.7000e-06
# Epoch 42/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 952s 4s/step - accuracy: 0.0526 - loss: 3.7970 - val_accuracy: 0.0800 - val_loss: 3.4305 - learning_rate: 2.7000e-06
# Epoch 43/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 947s 4s/step - accuracy: 0.0503 - loss: 3.8047 - val_accuracy: 0.0617 - val_loss: 3.6807 - learning_rate: 2.7000e-06
# Epoch 44/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 956s 4s/step - accuracy: 0.0517 - loss: 3.7715 - val_accuracy: 0.0780 - val_loss: 3.4177 - learning_rate: 2.7000e-06
# Epoch 45/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 954s 4s/step - accuracy: 0.0533 - loss: 3.8000 - val_accuracy: 0.0800 - val_loss: 3.4129 - learning_rate: 2.7000e-06
# Epoch 46/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 959s 4s/step - accuracy: 0.0593 - loss: 3.7601 - val_accuracy: 0.0867 - val_loss: 3.3912 - learning_rate: 2.7000e-06
# Epoch 47/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 947s 4s/step - accuracy: 0.0558 - loss: 3.7802 - val_accuracy: 0.0867 - val_loss: 3.4158 - learning_rate: 2.7000e-06
# Epoch 48/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 924s 4s/step - accuracy: 0.0571 - loss: 3.7880 - val_accuracy: 0.0713 - val_loss: 3.4477 - learning_rate: 2.7000e-06
# Epoch 49/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 915s 4s/step - accuracy: 0.0517 - loss: 3.7756 - val_accuracy: 0.0934 - val_loss: 3.3853 - learning_rate: 2.7000e-06
# Epoch 50/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 905s 4s/step - accuracy: 0.0551 - loss: 3.7795 - val_accuracy: 0.0925 - val_loss: 3.3795 - learning_rate: 2.7000e-06
# Restoring model weights from the end of the best epoch: 50.
#
# 50 épocas en 763.2 min

# %% [markdown]
# ## 5 · Curvas de entrenamiento

# %%
applyStyle()
import matplotlib.pyplot as plt

epocas = range(1, len(historia["loss"]) + 1)
figura, ejes = plt.subplots(1, 2, figsize=(11, 4.2))

ejes[0].plot(epocas, historia["accuracy"], color=SERIE_1, label="Entrenamiento")
ejes[0].plot(epocas, historia["val_accuracy"], color=SERIE_2, label="Validación")
ejes[0].set(title=f"{RUN_NAME} · Exactitud", xlabel="Época", ylim=(0, 1))
ejes[0].legend(loc="lower right")

ejes[1].plot(epocas, historia["loss"], color=SERIE_1, label="Entrenamiento")
ejes[1].plot(epocas, historia["val_loss"], color=SERIE_2, label="Validación")
ejes[1].set(title=f"{RUN_NAME} · Pérdida", xlabel="Época")
ejes[1].legend(loc="upper right")

figura.tight_layout()
figura.savefig(IMGS / "training_history.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 6 · Evaluación
#
# Dos conjuntos: `test` (20%, métrica principal) y `validate` (10%, el que
# monitorean los callbacks).

# %%
metricas = {
    "test": evalStats.evaluar(modelo, dsTest, clases),
    "validate": evalStats.evaluar(modelo, dsVal, clases),
}

pd.DataFrame([
    {k: round(v, 4) if isinstance(v, float) else v
     for k, v in m.items()
     if k in ("num_samples", "accuracy", "top3_accuracy",
              "macro_f1", "weighted_f1", "macro_precision", "macro_recall")}
    for m in metricas.values()
], index=list(metricas.keys()))
# Out:
# 2026-09-13 18:33:05.265035: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-09-13 18:34:15.774597: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
#           num_samples  accuracy  top3_accuracy  macro_precision  macro_recall  \
# test             2062    0.0951         0.2396           0.0607        0.0983
# validate         1038    0.0925         0.2495           0.0505        0.0963
#
#           macro_f1  weighted_f1
# test        0.0543       0.0581
# validate    0.0475       0.0508

# %% [markdown]
# ## 7 · Matriz de confusión

# %%
_ = plotConfusionMatrix(
    metricas["test"],
    f"Matriz de confusión · prueba · {RUN_NAME}",
)
plt.savefig(IMGS / "confusion_test.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 8 · Confusiones principales

# %%
confusiones = evalStats.confusionesPrincipales(metricas["test"])
pd.DataFrame(confusiones).head(10)
# Out:
#                      real          predicha  casos   tasa
# 0           eurema_albula   taygetis_sylvia     23  0.742
# 1       taygetis_virgilia   taygetis_sylvia     21  0.913
# 2         eueides_vibilia  heliconius_doris     19  0.633
# 3         taygetis_laches   taygetis_sylvia     19  0.613
# 4         taygetina_kerea   taygetis_sylvia     17  0.630
# 5   pareuptychia_ocirrhoe  heliconius_erato     17  0.607
# 6          phoebis_sennae   taygetis_sylvia     17  0.567
# 7      urbanus_simplicius    urbanus_procne     17  0.567
# 8            pyrgus_orcus     adelpha_alala     17  0.500
# 9  dismorphia_theucharila  heliconius_erato     16  0.552

# %% [markdown]
# ## 9 · Versionado

# %%
modelo.save(RUN_DIR / "model.keras")
registro.writeJson(RUN_DIR / "history.json", historia)
registro.writeJson(RUN_DIR / "metrics.json", {
    "run_id": RUN_ID,
    "class_names": clases,
    "splits": metricas,
    "top_confusions": {
        s: evalStats.confusionesPrincipales(m) for s, m in metricas.items()
    },
})

configuracion = {
    "run_id": RUN_ID,
    "name": RUN_NAME,
    "architecture": ARQUITECTURA,
    "role": ROL,
    "notes": NOTAS,
    "num_classes": len(clases),
    "hyperparameters": {
        "img_size": list(TAMANO),
        "batch_size": LOTE,
        "epochs_budget": EPOCAS,
        "epochs_ran": len(historia["loss"]),
        "learning_rate": TASA_APRENDIZAJE,
        "early_stopping_patience": PACIENCIA,
        "class_weights": "balanced",
        "seed": SEMILLA,
        "finetuning": FRACCION_DESCONGELADA,
        "backbone": f"{ARQUITECTURA}/imagenet",
    },
    "environment": {
        "python": platform.python_version(),
        "tensorflow": tf.__version__,
        "platform": platform.platform(),
    },
    "started_at": inicio.isoformat(),
    "finished_at": fin.isoformat(),
    "training_minutes": round((fin - inicio).total_seconds() / 60, 1),
}
registro.writeJson(RUN_DIR / "run.json", configuracion)

registro.registerRun({
    "run_id": RUN_ID,
    "name": RUN_NAME,
    "architecture": ARQUITECTURA,
    "role": ROL,
    "finetuning": FRACCION_DESCONGELADA,
    "num_classes": len(clases),
    "epochs_ran": len(historia["loss"]),
    "training_minutes": configuracion["training_minutes"],
    "test_accuracy": metricas["test"]["accuracy"],
    "test_macro_f1": metricas["test"]["macro_f1"],
    "validate_accuracy": metricas["validate"]["accuracy"],
    "validate_macro_f1": metricas["validate"]["macro_f1"],
    "notes": NOTAS,
    "created_at": inicio.isoformat(),
})

if PROMOVER:
    registro.promoteRun(RUN_ID)

print(f"Run guardado en {RUN_DIR}")
# Out:
# Run guardado en /Users/cristiansandoval/Universidad/Semillero/ButterflyModeling/outputs/runs/20260913T104733Z_resnet50-v2

# %% [markdown]
# ## Resumen

# %%
pd.Series({
    "run_id": RUN_ID,
    "arquitectura": ARQUITECTURA,
    "clases": len(clases),
    "epocas": len(historia["loss"]),
    "minutos": configuracion["training_minutes"],
    "test_accuracy": round(metricas["test"]["accuracy"], 4),
    "test_top3": round(metricas["test"]["top3_accuracy"], 4),
    "test_macro_f1": round(metricas["test"]["macro_f1"], 4),
    "validate_accuracy": round(metricas["validate"]["accuracy"], 4),
    "validate_macro_f1": round(metricas["validate"]["macro_f1"], 4),
}).to_frame("valor")
# Out:
#                                           valor
# run_id             20260913T104733Z_resnet50-v2
# arquitectura                        resnet50_v2
# clases                                       79
# epocas                                       50
# minutos                                   763.2
# test_accuracy                            0.0951
# test_top3                                0.2396
# test_macro_f1                            0.0543
# validate_accuracy                        0.0925
# validate_macro_f1                        0.0475
